# %% [markdown]
# # 3-2 환경과 자료구조 확인
# 셀을 위에서 아래로 실행하고 출력만 확인합니다.

# %%
import sys
print("현재 사용하는 Python:")
print(sys.executable)

# %% [markdown]
# ## list — 순서로 찾는 여러 값

# %%
scores = [72, 85, 90, 68]
print(scores)
print("첫 번째 값:", scores[0])

# %% [markdown]
# ## dict — 이름으로 찾는 여러 값

# %%
student = {"name": "민준", "score": 85, "passed": True}
print(student)
print("이름:", student["name"])
print("점수:", student["score"])
