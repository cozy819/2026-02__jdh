# %% [markdown]
# # 4-2 실습 · AI와 CSV 읽기
#
# 원본 파일: `../data/04-library-data.csv`
#
# 4-1의 Excel과 내용이 같은 CSV를 사용합니다. AI에게 한 번에 전부 맡기지 않고, 답을 확인한 뒤 다음 요청으로 넘어갑니다.

# %% [markdown]
# ## 1. 자료 이해
#
# AI에게 이 CSV가 어떤 자료인지, 4-1의 Excel과 내용이 다른지 먼저 묻습니다. 아직 코드는 만들지 않습니다.

# %% [markdown]
# ## 2. 평균 계산
#
# AI에게 일별 방문자 수 평균과 일별 대출 권수 평균을 계산하고, 아래 셀에 결과를 출력하는 코드를 만들게 합니다.

# %%
# AI가 평균을 계산하고 print()로 표시하는 코드를 이 셀에 작성합니다.

# %% [markdown]
# ## 3. 축 선택
#
# 추세선을 만들기 전에 x축과 y축에 넣을 수 있는 열을 AI에게 설명하게 합니다. 이번에는 x축 `date`, y축 `visitors`를 고릅니다.

# %% [markdown]
# ## 4. 그래프와 5일 평균 추세선
#
# AI에게 회색 원자료와 주황 5일 평균 추세선을 한 그래프에 겹치고, 데이터 총 행 수·열 이름·두 평균도 출력하게 합니다.

# %%
# AI가 CSV를 읽고 검토용 숫자와 그래프를 만드는 코드를 이 셀에 작성합니다.

# %% [markdown]
# ## 5. 결과 검토
#
# - 데이터가 60행 3열인가?
# - 열 이름이 `date`, `visitors`, `borrowed_books`인가?
# - 두 평균이 원본 CSV를 다시 계산한 값과 같은가?
# - 그래프의 x축은 `date`, y축은 `visitors`인가?
# - 회색 원자료와 주황 5일 평균 추세선이 함께 보이는가?
