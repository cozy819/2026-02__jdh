# %% [markdown]
# # 4-1 실습 · Excel 자료를 그래프로 만들기
#
# 원본 파일: `../data/04-library-data.xlsx`
#
# Excel에서 원본을 확인한 뒤 AI에게 세 번으로 나누어 요청합니다. 먼저 데이터가 무엇을 말하는지 묻고, 알맞은 그래프를 추천받은 뒤, 이 Notebook에 그래프와 확인용 print 코드를 작성하게 합니다. Excel은 `pandas`가 아니라 `openpyxl`로 읽습니다.

# %% [markdown]
# ## 확인한 머리글
#
# - `date`
# - `visitors`
# - `borrowed_books`
#
# AI가 추천한 그래프와 사용할 열을 확인한 뒤 아래 셀을 채웁니다.

# %%
# AI가 작성한 데이터 확인 print 코드와 Matplotlib 코드를 이 셀에서 실행합니다.

# %% [markdown]
# ## 실행 뒤 확인
#
# - 날짜 60개가 빠짐없이 사용됐는가?
# - 실행 결과에 데이터 총 행 수와 열 이름이 표시됐는가?
# - 그래프에 사용한 열이 AI가 추천한 열과 같은가?
# - Excel의 첫 날짜와 마지막 날짜가 그래프 범위와 맞는가?
# - 날짜 글자가 겹치지 않는가?
